# %%
import nemo.collections.asr as nemo_asr
import os

# %%
from flwr.common import Scalar
import flwr as fl
import torch
import numpy as np
from typing import Dict, Tuple, List
from collections import OrderedDict
import pytorch_lightning as ptl
from omegaconf import open_dict

def count_lines(file_path):
    with open(file_path, 'r') as file:
        line_count = sum(1 for line in file)
    return line_count

def set_parameters(net: torch.nn.Module, parameters: List[np.ndarray]) -> None:
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)
        
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

def set_config(net, train_manifest_path, test_manifest_path):
    cfg = net.cfg
    with open_dict(cfg):
        cfg.train_ds.manifest_filepath = train_manifest_path
        cfg.train_ds.batch_size = 1
        cfg.train_ds.num_workers = 8
        cfg.train_ds.is_tarred = False
        #   cfg.train_ds.pin_memory=True \
        cfg.test_ds.manifest_filepath = test_manifest_path
        cfg.test_ds.batch_size = 1
        cfg.test_ds.num_workers = 8

        # Validation dataset  (Use test dataset as validation, since we train using train + dev)
        cfg.validation_ds.manifest_filepath = test_manifest_path
        cfg.validation_ds.batch_size = 1
        cfg.validation_ds.num_workers = 8
        cfg.train_ds.is_tarred = False

        cfg.spec_augment.freq_mask: 0
        cfg.spec_augment.time_mask: 0
        
        # Optimizer and Scheduler
        cfg.optim.name = 'adamw'
        cfg.optim.lr = 1.0e-4
        cfg.optim.betas = [0.9, 0.98]
        cfg.optim.weight_decay = 0.0005
        cfg.optim.sched.max_steps = (10 // 1) * 1
        cfg.optim.sched.name = "CosineAnnealing"
        cfg.optim.sched.min_lr = 1.0e-7
        cfg.optim.sched.warmup_steps = 0
            # Remove unnecessary parameters
        if 'warmup_ratio' in cfg.optim.sched:
            del cfg.optim.sched['warmup_ratio']
        if 'hold_ratio' in cfg.optim.sched:
            del cfg.optim.sched['hold_ratio']
        if 'hold_steps' in cfg.optim.sched:
            del cfg.optim.sched['hold_steps']
        if 'decay_rate' in cfg.optim.sched:
            del cfg.optim.sched['decay_rate']
    
    net.cfg = net._cfg
    net.setup_training_data(cfg.train_ds)
    net.setup_validation_data(cfg.validation_ds)
    net.setup_optimization(cfg.optim)
    net.spec_augmentation = net.from_config_dict(cfg.spec_augment)
    

class NemoASRClient(fl.client.NumPyClient):
    def __init__(self, model, train_manifest_path, test_manifest_path):
        set_config(model, train_manifest_path, test_manifest_path)
        self.model = model
        if torch.cuda.is_available():
          accelerator = 'gpu'
        else:
          accelerator = 'cpu'
        print(f"Using {self.model.cfg.validation_ds.manifest_filepath} testdatamanifest")
        trainer = ptl.Trainer(devices=1,
                              accelerator=accelerator,
                              max_epochs=1,
                              accumulate_grad_batches=1,
                              enable_checkpointing=False,
                              logger=False,
                              log_every_n_steps=1,
                              check_val_every_n_epoch=2)
        self.trainer = trainer

        self.model.set_trainer(trainer)


    def get_parameters(self, config: Dict[str, Scalar]) -> List[np.ndarray]:
        return get_parameters(self.model)
    
    def fit(
        self, parameters: List[np.ndarray], config: Dict[str, Scalar]
    ) -> Tuple[List[np.ndarray], int, Dict[str, Scalar]]:
        set_parameters(self.model, parameters)
        self.trainer.fit(self.model)
        # params, num train samples, other metrics
        return get_parameters(self.model), count_lines(self.model.cfg.train_ds.manifest_filepath), {}

    def evaluate(
            self, parameters: List[np.ndarray], config: Dict[str, Scalar]
        ) -> Tuple[float, int, Dict[str, Scalar]]:
        
        if config.get("evaluate"):
            set_parameters(self.model, parameters)
            test_results = self.trainer.validate(self.model)
            test_result = test_results[0]
            loss = test_result.get('test_loss', 0.0)
            wer = test_result.get('test_wer', 0.0) 
            return loss, count_lines(self.model.cfg.validation_ds.manifest_filepath), {"wer": wer}
        return 0, 0, {}

# %%
from collections import defaultdict
import json
import os
def create_speaker_manifests(train_manifest_path, output_dir):
    with open(train_manifest_path, 'r') as f:
        lines = f.readlines()
    
    speaker_data = defaultdict(list)
    
    for line in lines:
        data = json.loads(line)
        speaker_id = data['audio_filepath'].split('/')[-2]
        speaker_data[speaker_id].append(data)
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    llspeaker_manifest_paths = set()
    for speaker_id, data in speaker_data.items():
        speaker_manifest_path = os.path.join(output_dir, f"{speaker_id}_manifest.json")
        with open(speaker_manifest_path, 'w') as f:
            for entry in data:
                f.write(json.dumps(entry) + '\n')
        llspeaker_manifest_paths.add(speaker_manifest_path)
    
    return llspeaker_manifest_paths

fed_manifests_folder_path = "timit-dataset/federated-manifests"
# Example usage
speaker_manifest_paths = create_speaker_manifests("timit-dataset/train-manifest.clean.json", fed_manifests_folder_path)

# %%
def client_fn(cid: str):
    asr_model = nemo_asr.models.EncDecCTCModelBPE.from_pretrained(model_name="stt_en_squeezeformer_ctc_xsmall_ls")
    
    # Pop a manifest path from the set
    train_manifest_path = speaker_manifest_paths.pop()
    test_manifest_path = "timit-dataset/test-manifest.clean.json"
    
    #return NemoASRClient(asr_model, train_manifest_path, test_manifest_path).to_client()
    return NemoASRClient(asr_model, train_manifest_path, train_manifest_path).to_client()

# %%
import flwr as fl


def on_fit_config_fn(rnd: int):
    return {"epoch": rnd}

def on_evaluate_config_fn(rnd: int):
    return {"epoch": rnd, "evaluate": True}

def evaluate_fn(server_round, parameters, config):
    # Load global model
    global_model = nemo_asr.models.EncDecCTCModelBPE.from_pretrained(model_name="stt_en_squeezeformer_ctc_xsmall_ls")
    set_config(global_model, "timit-dataset/train-manifest.clean.json", "timit-dataset/test-manifest.clean.json")
    set_parameters(global_model, parameters)
    
    # Perform evaluation
    trainer = ptl.Trainer(devices=1, accelerator='gpu' if torch.cuda.is_available() else 'cpu')
    results = trainer.validate(global_model)
    loss = results[0].get('test_loss', 0.0)
    wer = results[0].get('test_wer', 0.0)

    return loss, {"wer": wer}
    #return 0, {"wer": 0}

strategy = fl.server.strategy.FedAvg(
    on_fit_config_fn=on_fit_config_fn,
    on_evaluate_config_fn=on_evaluate_config_fn,
    evaluate_fn=evaluate_fn
)

#num_clients = len(speaker_manifest_paths)
num_clients = 2
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=num_clients,
    client_resources={"num_cpus": 1, "num_gpus": 1},  # Adjust as needed
    config=fl.server.ServerConfig(num_rounds=1),
    strategy=strategy,
)
# Out:
# INFO :      Starting Flower simulation, config: num_rounds=1, no round_timeout
# 2024-07-12 22:16:23,540	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'memory': 4154695680.0, 'CPU': 8.0, 'node:172.26.121.70': 1.0, 'node:__internal_head__': 1.0, 'GPU': 1.0, 'accelerator_type:G': 1.0, 'object_store_memory': 2077347840.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 1}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (ClientAppActor pid=27786) /home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/lightning_utilities/core/imports.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
# (ClientAppActor pid=27786)   import pkg_resources
# (ClientAppActor pid=27786) /home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/pkg_resources/__init__.py:2871: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('pyannote')`.
# (ClientAppActor pid=27786) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (ClientAppActor pid=27786)   declare_namespace(pkg)
# (ClientAppActor pid=27786) /home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/pkg_resources/__init__.py:2871: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# (ClientAppActor pid=27786) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (ClientAppActor pid=27786)   declare_namespace(pkg)
# (ClientAppActor pid=27786) /home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/lightning_fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning_fabric')`.
# (ClientAppActor pid=27786) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (ClientAppActor pid=27786) /home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/pytorch_lightning/__init__.py:37: Deprecated call to `pkg_resources.declare_namespace('pytorch_lightning')`.
# (ClientAppActor pid=27786) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) Exception in initializer:
# (ClientAppActor pid=27786) Traceback (most recent call last):
# (ClientAppActor pid=27786)   File "/usr/lib/python3.10/concurrent/futures/process.py", line 233, in _process_worker
# (ClientAppActor pid=27786)     initializer(*initargs)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/torch/_inductor/codecache.py", line 2554, in _async_compile_initializer
# (ClientAppActor pid=27786)     signal.signal(signal.SIGINT, signal.SIG_IGN)
# (ClientAppActor pid=27786)   File "/home/robert/.virtualenvs/ForschungsprojektA/lib/python3.10/site-packages/ray/_private/utils.py", line 1880, in _signal_monkey_patch
# (ClientAppActor pid=27786)     raise ValueError(
# (ClientAppActor pid=27786) ValueError: Can't set signal handler for SIGINT while SIGINT is being deferred within a DeferSigint context.
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:33 cloud:58] Found existing object /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:33 cloud:64] Re-using file from: /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:33 common:815] Instantiating model from pre-trained checkpoint
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:16:34 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
# (ClientAppActor pid=27786)     Train config :
# (ClientAppActor pid=27786)     manifest_filepath: /data/tarred_train/tarred_audio_manifest.json
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 32
# (ClientAppActor pid=27786)     shuffle: true
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)     trim_silence: false
# (ClientAppActor pid=27786)     max_duration: 16.7
# (ClientAppActor pid=27786)     min_duration: 0.1
# (ClientAppActor pid=27786)     is_tarred: true
# (ClientAppActor pid=27786)     tarred_audio_filepaths: /data/tarred_train/audio__OP_0..511_CL_.tar
# (ClientAppActor pid=27786)     shuffle_n: 2048
# (ClientAppActor pid=27786)     bucketing_strategy: synced_randomized
# (ClientAppActor pid=27786)     bucketing_batch_size: null
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:16:34 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
# (ClientAppActor pid=27786)     Validation config :
# (ClientAppActor pid=27786)     manifest_filepath:
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-test-other.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-test-clean.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-dev-other.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-dev-clean.json
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 8
# (ClientAppActor pid=27786)     shuffle: false
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:16:34 modelPT:189] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
# (ClientAppActor pid=27786)     Test config :
# (ClientAppActor pid=27786)     manifest_filepath: null
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 16
# (ClientAppActor pid=27786)     shuffle: false
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 mixins:172] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 features:305] PADDING: 0
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 save_restore_connector:263] Model EncDecCTCModelBPE was successfully restored from /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 collections:196] Dataset loaded with 10 files totalling 0.01 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 collections:197] 0 files were filtered totalling 0.00 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 collections:196] Dataset loaded with 10 files totalling 0.01 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 collections:197] 0 files were filtered totalling 0.00 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 modelPT:770] Optimizer config = AdamW (
# (ClientAppActor pid=27786)     Parameter Group 0
# (ClientAppActor pid=27786)         amsgrad: False
# (ClientAppActor pid=27786)         betas: [0.9, 0.98]
# (ClientAppActor pid=27786)         capturable: False
# (ClientAppActor pid=27786)         differentiable: False
# (ClientAppActor pid=27786)         eps: 1e-08
# (ClientAppActor pid=27786)         foreach: None
# (ClientAppActor pid=27786)         fused: None
# (ClientAppActor pid=27786)         lr: 0.0001
# (ClientAppActor pid=27786)         maximize: False
# (ClientAppActor pid=27786)         weight_decay: 0.0005
# (ClientAppActor pid=27786)     )
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:16:34 lr_scheduler:923] Scheduler "<nemo.core.optim.lr_scheduler.CosineAnnealing object at 0x7f13dba5e020>"
# (ClientAppActor pid=27786)     will be used during training (effective maximum steps = 10) -
# (ClientAppActor pid=27786)     Parameters :
# (ClientAppActor pid=27786)     (warmup_steps: 0
# (ClientAppActor pid=27786)     min_lr: 1.0e-07
# (ClientAppActor pid=27786)     max_steps: 10
# (ClientAppActor pid=27786)     )
# (ClientAppActor pid=27786) Using timit-dataset/federated-manifests/MDLR0_manifest.json testdatamanifest
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:16:34 modelPT:652] Trainer wasn't specified in model constructor. Make sure that you really wanted it.
# (ClientAppActor pid=27786) GPU available: True (cuda), used: True
# (ClientAppActor pid=27786) TPU available: False, using: 0 TPU cores
# (ClientAppActor pid=27786) HPU available: False, using: 0 HPUs
# INFO :      Received initial parameters from one random client
# INFO :      Evaluating initial global parameters
# [NeMo I 2024-07-12 22:16:35 cloud:58] Found existing object /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# [NeMo I 2024-07-12 22:16:35 cloud:64] Re-using file from: /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo
# [NeMo I 2024-07-12 22:16:35 common:815] Instantiating model from pre-trained checkpoint
# [NeMo I 2024-07-12 22:16:35 mixins:172] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# [NeMo W 2024-07-12 22:16:35 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /data/tarred_train/tarred_audio_manifest.json
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 16.7
#     min_duration: 0.1
#     is_tarred: true
#     tarred_audio_filepaths: /data/tarred_train/audio__OP_0..511_CL_.tar
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2024-07-12 22:16:35 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath:
#     - /data/librispeech/LibriSpeech/librivox-test-other.json
#     - /data/librispeech/LibriSpeech/librivox-test-clean.json
#     - /data/librispeech/LibriSpeech/librivox-dev-other.json
#     - /data/librispeech/LibriSpeech/librivox-dev-clean.json
#     sample_rate: 16000
#     batch_size: 8
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo W 2024-07-12 22:16:35 modelPT:189] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2024-07-12 22:16:35 features:305] PADDING: 0
# [NeMo I 2024-07-12 22:16:36 save_restore_connector:263] Model EncDecCTCModelBPE was successfully restored from /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# [NeMo I 2024-07-12 22:16:36 collections:196] Dataset loaded with 4620 files totalling 3.94 hours
# [NeMo I 2024-07-12 22:16:36 collections:197] 0 files were filtered totalling 0.00 hours
# [NeMo I 2024-07-12 22:16:36 collections:196] Dataset loaded with 1680 files totalling 1.44 hours
# [NeMo I 2024-07-12 22:16:36 collections:197] 0 files were filtered totalling 0.00 hours
# [NeMo W 2024-07-12 22:16:36 modelPT:652] Trainer wasn't specified in model constructor. Make sure that you really wanted it.
# [NeMo I 2024-07-12 22:16:36 modelPT:770] Optimizer config = AdamW (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.98]
#         capturable: False
#         differentiable: False
#         eps: 1e-08
#         foreach: None
#         fused: None
#         lr: 0.0001
#         maximize: False
#         weight_decay: 0.0005
#     )
# [NeMo I 2024-07-12 22:16:36 lr_scheduler:923] Scheduler "<nemo.core.optim.lr_scheduler.CosineAnnealing object at 0x7ff3d073b130>"
#     will be used during training (effective maximum steps = 10) -
#     Parameters :
#     (warmup_steps: 0
#     min_lr: 1.0e-07
#     max_steps: 10
#     )
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# [NeMo W 2024-07-12 22:16:38 ctc_greedy_decoding:168] CTC decoding strategy 'greedy' is slower than 'greedy_batch', which implements the same exact interface. Consider changing your strategy to 'greedy_batch' for a free performance improvement.
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:she had your dark suit and greasy wash water all year
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:his captain was thin and haggard and his beautiful boots were worn and shabby
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:his captain was thin and haggard and his beautiful boots were worn and shabby
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:the reasons for this dive seemed foolish now
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:the reasons for the stive seemed foolish now
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:production may fall far below expectations
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:production may fall far below expectations
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:pizzerias are convenient for a quick lunch
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:pezareas are convenient for a quick lunch
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:put the butcher block table in the garage
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:put the butcher block table in the garrache
# [NeMo I 2024-07-12 22:16:38 wer:334]
#
# [NeMo I 2024-07-12 22:16:38 wer:335] reference:drop five forms in the box before you go out
# [NeMo I 2024-07-12 22:16:38 wer:336] predicted:drop five forms in the box before you go out
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:her wardrobe consists of only skirts and blouses
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:her wardrobe consists of only skirts and blouses
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:elderly people are often excluded
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:elderly people are often excluded
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:she had yer dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:don't ask me to carry a oily rag like that
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:husky young man he said with mock distaste
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:husky young man he said withm distaste
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:ahah he thought a lush divorcee at last
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:haha he thought a lush divorcy at last
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:thus technical efficiency is achieved at the expense of actual experience
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:thus technical efficiency is achieved at the expense of actual experience
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:objects made of pewter are beautiful
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:objects made of pewter are beautiful
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:the morning dew on the spider web glistened in the sun
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:the morning dew on the spider web glistened in the sun
# [NeMo I 2024-07-12 22:16:39 wer:334]
#
# [NeMo I 2024-07-12 22:16:39 wer:335] reference:cheap stockings run the first time they're worn
# [NeMo I 2024-07-12 22:16:39 wer:336] predicted:cheap starkings run the first time they're worn
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:don't do charlie's dirty dishes
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:don't do charlie's dirdy dishes
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:calcium makes bones and teeth strong
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:calcium makes bones and teeth strong
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:she had your dark suit and greasy washwater all year
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:in wage negotiations the industry bargains as a unit with a single union
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:in wage negotiations the industry bargains as a unit with a single union
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:heave on those ropes the boat's come unstuck
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:heave on those ropes the boats come unstuck
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:materials ceramic modeling clay red white or buff
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:materials syremic modelling clay red white or buff
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:artificial intelligence is for real
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:artificial intelligence is for real
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:the small boy put the worm on the hook
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:the small boy put the worm on the hook
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:a chosen few will become generals
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:a chosen few will become generals
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:only the most accomplished artists obtain popularity
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:only the most accomplished artists obtain popularity
# [NeMo I 2024-07-12 22:16:40 wer:334]
#
# [NeMo I 2024-07-12 22:16:40 wer:335] reference:the fish began to leap frantically on the surface of the small lake
# [NeMo I 2024-07-12 22:16:40 wer:336] predicted:the fish began to leap frantically on the surface of the small lake
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:she had your dark suit and greasy wash water all year
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:dances alternated with sung or spoken verses
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:dances alternated with sung or spoken verses
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:my father ran him off here six years ago
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:my father rn him off here six years ago
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:here he is quite persuasively the very embodiment of meanness and slyness
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:here he is quite persuasively the very embodiment of meanness and slyness
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:the cat's meow always hurts my ears
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:the cats me out always hurts my ears
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:cliff was soothed by the luxurious massage
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:cliff was soothed by the luxurious message
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:each untimely income loss coincided with the breakdown of a heating system part
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:each untimely income loss coincided with the break down of a heating system part
# [NeMo I 2024-07-12 22:16:41 wer:334]
#
# [NeMo I 2024-07-12 22:16:41 wer:335] reference:jane may earn more money by working hard
# [NeMo I 2024-07-12 22:16:41 wer:336] predicted:jane may earn more money by working hard
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:youngsters love common candy as treats
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:youngsters love common candy as treats
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:don't ask me to carry an oil youor egg like that
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:he has never himself done anything for which to be hated which of us has
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:he has never himself doneything for which to be hated which of us has
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:be excited and don't identify yourself
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:be excited and don't identify yourself
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:sometimes he coincided with my father's being at home
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:sometimes he coincided with my father's being at home
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:the bungalow was pleasantly situated near the shore
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:the bungalow was pleasantly situated near the shore
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:are you looking for employment
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:are you looking for employment
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:a big goat idly ambled through the farmyard
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:a big goat idly amble to the farm yard
# [NeMo I 2024-07-12 22:16:42 wer:334]
#
# [NeMo I 2024-07-12 22:16:42 wer:335] reference:eating spinach nightly increases strength miraculously
# [NeMo I 2024-07-12 22:16:42 wer:336] predicted:eating spinitch nightly increasees strithe miraculously
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:at twilight on the twelfth day we'll have chablis
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:at twilight on the twelfth day will have shiblei
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:she had youer dark suit and greasy wash water all year
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:the socalled vegetable ivory is the hard endosperm of the eggsized seed
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:the so called vegetable ivory is the hard o sperm of the egg sized seed
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:how did one join them
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:how did one join them
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:dogs did something to one's ego
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:dogs did something to one's eago
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:the best way to learn is to solve extra problems
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:the best way to learn is to solve extra problems
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:she wore warm fleecy woolen overalls
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:she wore warm fleecy woolen overalls
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:ralph controlled the stopwatch from the bleachers
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:ralph controlled a stop watch from the bleachers
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:this brochure is particularly informative for a prospective buyer
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:this brochure is particularly informative for a prospective buyer
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:why charge money for such garbage
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:why charge money for such garbage
# [NeMo I 2024-07-12 22:16:43 wer:334]
#
# [NeMo I 2024-07-12 22:16:43 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:43 wer:336] predicted:she had you dark suit in grisy washwater all year
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:often dominant stress simply indicates a centering of attention or emotion
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:often dominant stress simply indicates a centering of attention or emotion
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:he had left her inviolate thinking familiarity would gentle her in time
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:he had left her in violet thinking familiarity would gentle her in time
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:broil or toast as usual
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:broil or toast as usual
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:the emblem depicts the acropolis all aglow
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:the amblem depicts the acropolis all aglow
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:military personnel are expected to obey government orders
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:military personel are expected to obey government orders
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:only lawyers love millionaires
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:only lawyers love millionaires
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:if carol comes tomorrow have her arrange for a meeting at two
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:if carol comes to morrow have her arrange for meeting it too
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:his shoulder felt as if it were broken
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:his shoulder felt as if it were broken
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:she had  your dark suit and greasy wash one all year
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:don't ask me to carry all the rag like that
# [NeMo I 2024-07-12 22:16:44 wer:334]
#
# [NeMo I 2024-07-12 22:16:44 wer:335] reference:but within that framework he allowed for as much flexibility as possible
# [NeMo I 2024-07-12 22:16:44 wer:336] predicted:but whutd in that framework he allowed for as much flexibilly as possible
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:we came on as soon as we could
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:we came on as soon as we could
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:if necessary to replace both halves on grill sear cuts and allot extra time
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:if necessarity placed both halfs on grill sea cuts and a lot extra time
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:he stole a dime from a beggar
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:he stole the dip from a beggar
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:before thursday's exam review every formula
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:the four thirusid exam the view ofvery formula
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:they enjoy it when i audition
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:they enjoy it onhe i addition
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:jeff thought you argued in favor of a centrifuge purchase
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:jef thought you argued in favor of a senefuge purchase
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:john cleans shellfish for a living
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:john clean shelfish for a living
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:she had your dark suit and greasy wash water all year
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:don't ask me to carry an eorly rag like that
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:you took me by surprise
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:he took me by surprise
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:the heavens refused to give up their weeping
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:the heavens refused to give up their weeping
# [NeMo I 2024-07-12 22:16:45 wer:334]
#
# [NeMo I 2024-07-12 22:16:45 wer:335] reference:the idea of a central tank with lines to each house is not in itself a novelty
# [NeMo I 2024-07-12 22:16:45 wer:336] predicted:the idea of a central tank reliines each house is not in itself a novelty
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:destroy every file related to my audits
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:destroy of me far related to my audence
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:alice's ability to work without supervision is noteworthy
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:alice's ability to work without supervision is notworthy
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:bob papered over living room murals
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:by a paper over living of mureles
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:where were you while we were away
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:where were you while we were away
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:medieval society was based on hierarchies
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:but eeval society was based on hierarchies
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:she had your darck suit in greasy washwater all year
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:at the base of the rocky hillside they left their horses and climbed on foot
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:at the base of the rocky hillside they left their horses and climbed on foot
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:you young men get to be my age you won't take flu so lightly
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:you young men get to be my age you won't take flue so lightly
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:a woman met a famous author at a literary tea
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:a woman met a famous author at a literary tea
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:objects made of pewter are beautiful
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:objects made of pewter are beautiful
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:the morning dew on the spider web glistened in the sun
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:the morning dew on the spider web glistened in the sun
# [NeMo I 2024-07-12 22:16:46 wer:334]
#
# [NeMo I 2024-07-12 22:16:46 wer:335] reference:cheap stockings run the first time they're worn
# [NeMo I 2024-07-12 22:16:46 wer:336] predicted:cheap stockings run the first time theyre are worn
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:don't do charlie's dirty dishes
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:don't do charlie's dirty dishes
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:calcium makes bones and teeth strong
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:calsium makes bones and teeth strong
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:she had yo dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:however the litter remained augmented by several dozen lunchroom suppers
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:however the litter remained augmented by several dozen lunchroom suppers
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:books are for schnooks
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:books a a shnoks
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:to many experts this trend was inevitable
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:to many experts this tran was inevitable
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:a muscular abdomen is good for your back
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:a muscular abdimen is good for you back
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:the causeway ended abruptly at the shore
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:the causeway ended abruptly at the shore
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:those musicians harmonize marvelously
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:those musicians harmonize marvellously
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:please take this dirty table cloth to the cleaners for me
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:please take this dirty tablecloth to the cleaners for me
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:the carpet cleaners shampooed our oriental rug
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:the carpet cleaners shampooed our oriental rug
# [NeMo I 2024-07-12 22:16:47 wer:334]
#
# [NeMo I 2024-07-12 22:16:47 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:47 wer:336] predicted:she had your dark suit and greasy wash water all year
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:don't ask me to curre an oily rag like that
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:what obsessions had she picked up during these long nights of talk
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:what obsessions had she picked up during these long nights of talk
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:and possessed himself how
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:and possessed himself how
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:they will take a wedding trip later
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:they will take a wedding trip later
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:the emblem depicts the acropolis all aglow
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:the emblem depicts the acropolis all aglow
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:military personnel are expected to obey government orders
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:military personnel are expected to obey government orders
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:only lawyers love millionaires
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:only lawyers love millionaires
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:if carol comes tomorrow have her arrange for a meeting at two
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:if carroll comes to morrow have her arrange her meeting it too
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:his shoulder felt as if it were broken
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:his shoulder felt as if it were broken
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:she had your dark suit in greasy wash water all year
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:she had your dark suit in greasy washwater all year
# [NeMo I 2024-07-12 22:16:48 wer:334]
#
# [NeMo I 2024-07-12 22:16:48 wer:335] reference:don't ask me to carry an oily rag like that
# [NeMo I 2024-07-12 22:16:48 wer:336] predicted:don't ask me to carry an oily rag like that
# ...
# Validation DataLoader 0:  10%|█         | 1/10 [00:00<00:00,  9.86it/s][NeMo I 2024-07-12 22:21:12 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:335] reference:don't ask me to carry an oily rag like that
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:336] predicted:don't ask me to carry an oily rag like that
# Validation DataLoader 0:  20%|██        | 2/10 [00:00<00:00, 11.31it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:335] reference:it made no difference that most evidence points to an opposite conclusion
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:336] predicted:it made no difference that most evidence points to an opposite conclusion
# Validation DataLoader 0:  30%|███       | 3/10 [00:00<00:00, 12.05it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:335] reference:we haven't slept together since we started
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:336] predicted:we haven't slept together since we started
# Validation DataLoader 0:  40%|████      | 4/10 [00:00<00:00, 13.28it/s][NeMo I 2024-07-12 22:21:12 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:335] reference:melancholy obsession
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:336] predicted:melancholy obsession
# Validation DataLoader 0:  50%|█████     | 5/10 [00:00<00:00, 14.16it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:335] reference:scholastic aptitude is judged by standardized tests
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:12 wer:336] predicted:scholastic aptitude is judged by standardized tests
# Validation DataLoader 0:  60%|██████    | 6/10 [00:00<00:00, 14.77it/s][NeMo I 2024-07-12 22:21:13 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:335] reference:they all agree that the essay is barely intelligible
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:336] predicted:they all agree that the essay is barely intelligible
# Validation DataLoader 0:  70%|███████   | 7/10 [00:00<00:00, 15.15it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:335] reference:an adult male baboon's teeth are not suitable for eating shellfish
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:336] predicted:and adult male baboon's teeth are not suitable for eating shellfish
# Validation DataLoader 0:  80%|████████  | 8/10 [00:00<00:00, 15.60it/s][NeMo I 2024-07-12 22:21:13 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:335] reference:smash lightbulbs and their cash value will diminish to nothing
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:336] predicted:smash light bulbs and their cash value will diminish to nothing
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:00<00:00, 15.95it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:335] reference:continental drift is a geological theory
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 wer:336] predicted:continental drift is a geoogical thory
# Validation DataLoader 0: 100%|██████████| 10/10 [00:00<00:00, 15.81it/s]
# (ClientAppActor pid=27786) ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# (ClientAppActor pid=27786) ┃      Validate metric      ┃       DataLoader 0        ┃
# (ClientAppActor pid=27786) ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# (ClientAppActor pid=27786) │        global_step        │            0.0            │
# (ClientAppActor pid=27786) │         val_loss          │    1.5785198211669922     │
# (ClientAppActor pid=27786) │          val_wer          │    0.05882352963089943    │
# (ClientAppActor pid=27786) └───────────────────────────┴───────────────────────────┘
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 cloud:58] Found existing object /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 cloud:64] Re-using file from: /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 common:815] Instantiating model from pre-trained checkpoint
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 mixins:172] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:21:13 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
# (ClientAppActor pid=27786)     Train config :
# (ClientAppActor pid=27786)     manifest_filepath: /data/tarred_train/tarred_audio_manifest.json
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 32
# (ClientAppActor pid=27786)     shuffle: true
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)     trim_silence: false
# (ClientAppActor pid=27786)     max_duration: 16.7
# (ClientAppActor pid=27786)     min_duration: 0.1
# (ClientAppActor pid=27786)     is_tarred: true
# (ClientAppActor pid=27786)     tarred_audio_filepaths: /data/tarred_train/audio__OP_0..511_CL_.tar
# (ClientAppActor pid=27786)     shuffle_n: 2048
# (ClientAppActor pid=27786)     bucketing_strategy: synced_randomized
# (ClientAppActor pid=27786)     bucketing_batch_size: null
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:21:13 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
# (ClientAppActor pid=27786)     Validation config :
# (ClientAppActor pid=27786)     manifest_filepath:
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-test-other.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-test-clean.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-dev-other.json
# (ClientAppActor pid=27786)     - /data/librispeech/LibriSpeech/librivox-dev-clean.json
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 8
# (ClientAppActor pid=27786)     shuffle: false
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:21:13 modelPT:189] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
# (ClientAppActor pid=27786)     Test config :
# (ClientAppActor pid=27786)     manifest_filepath: null
# (ClientAppActor pid=27786)     sample_rate: 16000
# (ClientAppActor pid=27786)     batch_size: 16
# (ClientAppActor pid=27786)     shuffle: false
# (ClientAppActor pid=27786)     num_workers: 8
# (ClientAppActor pid=27786)     pin_memory: true
# (ClientAppActor pid=27786)     use_start_end_token: false
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:13 features:305] PADDING: 0
# (ClientAppActor pid=27786) [NeMo W 2024-07-12 22:21:14 modelPT:652] Trainer wasn't specified in model constructor. Make sure that you really wanted it.
# (ClientAppActor pid=27786) GPU available: True (cuda), used: True
# (ClientAppActor pid=27786) TPU available: False, using: 0 TPU cores
# (ClientAppActor pid=27786) HPU available: False, using: 0 HPUs
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 save_restore_connector:263] Model EncDecCTCModelBPE was successfully restored from /home/robert/.cache/torch/NeMo/NeMo_2.0.0rc0/stt_en_squeezeformer_ctc_xsmall_ls/4d9c4c04221bedd8427635f462c97561/stt_en_squeezeformer_ctc_xsmall_ls.nemo.
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 collections:196] Dataset loaded with 10 files totalling 0.01 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 collections:197] 0 files were filtered totalling 0.00 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 collections:196] Dataset loaded with 10 files totalling 0.01 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 collections:197] 0 files were filtered totalling 0.00 hours
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 modelPT:770] Optimizer config = AdamW (
# (ClientAppActor pid=27786)     Parameter Group 0
# (ClientAppActor pid=27786)         amsgrad: False
# (ClientAppActor pid=27786)         betas: [0.9, 0.98]
# (ClientAppActor pid=27786)         capturable: False
# (ClientAppActor pid=27786)         differentiable: False
# (ClientAppActor pid=27786)         eps: 1e-08
# (ClientAppActor pid=27786)         foreach: None
# (ClientAppActor pid=27786)         fused: None
# (ClientAppActor pid=27786)         lr: 0.0001
# (ClientAppActor pid=27786)         maximize: False
# (ClientAppActor pid=27786)         weight_decay: 0.0005
# (ClientAppActor pid=27786)     )
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:14 lr_scheduler:923] Scheduler "<nemo.core.optim.lr_scheduler.CosineAnnealing object at 0x7f13dbd026b0>"
# (ClientAppActor pid=27786)     will be used during training (effective maximum steps = 10) -
# (ClientAppActor pid=27786)     Parameters :
# (ClientAppActor pid=27786)     (warmup_steps: 0
# (ClientAppActor pid=27786)     min_lr: 1.0e-07
# (ClientAppActor pid=27786)     max_steps: 10
# (ClientAppActor pid=27786)     )
# (ClientAppActor pid=27786) Using timit-dataset/federated-manifests/MDLR0_manifest.json testdatamanifest
# (ClientAppActor pid=27786) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:she had your dark suit in greasy wash water all year
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:she had your dark suit in greasy wash water all year
# Validation DataLoader 0:  10%|█         | 1/10 [00:00<00:01,  8.62it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:don't ask me to carry an oily rag like that
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:don't ask me to carry an oily rag like that
# Validation DataLoader 0:  20%|██        | 2/10 [00:00<00:00, 10.55it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:it made no difference that most evidence points to an opposite conclusion
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:it made no difference that most evidence points to an opposite conclusion
# Validation DataLoader 0:  30%|███       | 3/10 [00:00<00:00, 11.14it/s][NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:we haven't slept together since we started
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:we haven't slept together since we started
# Validation DataLoader 0:  40%|████      | 4/10 [00:00<00:00, 11.42it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:melancholy obsession
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:melancholy obsession
# Validation DataLoader 0:  50%|█████     | 5/10 [00:00<00:00, 11.49it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:scholastic aptitude is judged by standardized tests
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:scholastic aptitude is judged by standardized tests
# Validation DataLoader 0:  60%|██████    | 6/10 [00:00<00:00, 11.58it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:they all agree that the essay is barely intelligible
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:they all agree that the essay is barely intelligible
# Validation DataLoader 0:  70%|███████   | 7/10 [00:00<00:00, 11.88it/s][NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:an adult male baboon's teeth are not suitable for eating shellfish
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:and adult male baboon's teeth are not suitable for eating shellfish
# Validation DataLoader 0:  80%|████████  | 8/10 [00:00<00:00, 12.12it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:335] reference:smash lightbulbs and their cash value will diminish to nothing
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:15 wer:336] predicted:smash light bulbs and their cash value will diminish to nothing
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:00<00:00, 12.58it/s]
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:16 wer:334]
# (ClientAppActor pid=27786)
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:16 wer:335] reference:continental drift is a geological theory
# (ClientAppActor pid=27786) [NeMo I 2024-07-12 22:21:16 wer:336] predicted:continental drift is a geoogical thory
# Validation DataLoader 0: 100%|██████████| 10/10 [00:00<00:00, 12.93it/s]
# Validation DataLoader 0: 100%|██████████| 10/10 [00:00<00:00, 12.80it/s]
# (ClientAppActor pid=27786) ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# (ClientAppActor pid=27786) ┃      Validate metric      ┃       DataLoader 0        ┃
# (ClientAppActor pid=27786) ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# (ClientAppActor pid=27786) │        global_step        │            0.0            │
# (ClientAppActor pid=27786) │         val_loss          │    1.5785198211669922     │
# (ClientAppActor pid=27786) │          val_wer          │    0.05882352963089943    │
# (ClientAppActor pid=27786) └───────────────────────────┴───────────────────────────┘
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 1 round(s) in 147.74s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'wer': [(0, 0.0), (1, 0.0)]}
# INFO :
# History (loss, distributed):
# 	round 1: 0.0
# History (loss, centralized):
# 	round 0: 0.0
# 	round 1: 0.0
# History (metrics, centralized):
# {'wer': [(0, 0.0), (1, 0.0)]}
